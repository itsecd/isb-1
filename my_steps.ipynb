#  иЫтКитиДЫЬ ЯЬЫФтЫЬ чтЬ сИ1тие Дсе4елЬ 21Йи+
# КетсФ Ы1 иЙ2>тЬчЫЬсти иЫЛЬ+<14ии Д тексте ОиЛ+
# ЬД1Ыие 8тК иЙ2>тЬчЫЬст7 Кст+1ЫФет 1 Д<есте с ЫеШ Кст+
# 1ЫФет и ДЬЙ<ЬИЫЬст7 сИ1т7 текст

# %% [markdown]
# # STEP 3

# %% [markdown]
# # Ь -> о
# # Ы -> н
# # 7 -> ь

# %% [markdown]
# если сн1ч1л1 Я+и<енФть 1лЕо+ит< к+иЯтоЕ+1ЛическоЕо Я+ео2+
# 1ЙоД1ниФ r1нн>М то ок1ИетсФ что 1лЕо+
# ит< сИ1тиФ не <оИет 8ЛЛектиДно +12от1ть н1 ОиЛ+
# отекст1М Мо+оОиМ к+иЯто1лЕо+ит<оД сИ1ть ОиЛ+
# отекст Десь<1 тФИело Яо тоШ Я+остоШ Я+ичине что к+иЯ-+
# тоЕ+
# 1Лическ1Ф систе<1 rолИн1 лУ2><и rостКЯн><и сЯосо21<и +
# иЙ21ДлФть ОиЛ+отекст от очеДиrн>М ДнКт+
# енниМ Й1Диси<остеШ 1 Яото<К еЕо 8нт+
# оЯиФ 2Кrет Десь<1 Д>сокоШ и КИ точно н1<ноЕо Д>Ое че<+
#  К отк+>тоЕо текст1 Я+еrст1Дить се2е 1лЕо+
# ит< сИ1тиФ кото+>Ш 2> Мо+
# оОо сИи<1л Й1ОК<ленн>е r1нн>е rоДольно тФИело Деrь r1Ие+
#  интКитиДно ЯонФтно что сИ1тие Дсе4ело 21Йи+
# КетсФ н1 иЙ2>точности инЛо+<14ии Д тексте ОиЛ+
# оД1ние 8тК иЙ2>точность Кст+1нФет 1 Д<есте с неШ Кст+
# 1нФет и ДоЙ<оИность сИ1ть текст

# %% [markdown]
# # STEP 3

# %% [markdown]
# # 1 -> а
# # И -> ж
# # < -> м

# %% [markdown]
# если сначала Я+именФть алЕо+итм к+иЯтоЕ+аЛическоЕо Я+ео2+
# аЙоДаниФ rанн>М то окажетсФ что алЕо+
# итм сжатиФ не может 8ЛЛектиДно +а2отать на ОиЛ+
# отекстаМ Мо+оОиМ к+иЯтоалЕо+итмоД сжать ОиЛ+
# отекст Десьма тФжело Яо тоШ Я+остоШ Я+ичине что к+иЯ-+
# тоЕ+
# аЛическаФ система rолжна лУ2>ми rостКЯн>ми сЯосо2ами +
# иЙ2аДлФть ОиЛ+отекст от очеДиrн>М ДнКт+
# енниМ ЙаДисимостеШ а ЯотомК еЕо 8нт+
# оЯиФ 2Кrет Десьма Д>сокоШ и Кж точно намноЕо Д>Ое чем+
#  К отк+>тоЕо текста Я+еrстаДить се2е алЕо+
# итм сжатиФ кото+>Ш 2> Мо+
# оОо сжимал ЙаОКмленн>е rанн>е rоДольно тФжело Деrь rаже+
#  интКитиДно ЯонФтно что сжатие Дсе4ело 2аЙи+
# КетсФ на иЙ2>точности инЛо+ма4ии Д тексте ОиЛ+
# оДание 8тК иЙ2>точность Кст+анФет а Дместе с неШ Кст+
# анФет и ДоЙможность сжать текст

# %% [markdown]
# # STEP 4

# %% [markdown]
# # r -> д
# # Е -> г
# # + -> р
# # Ф -> я

# %% [markdown]
# если сначала Ярименять алгоритм криЯтограЛического Ярео2р
# аЙоДания данн>М то окажется что алгор
# итм сжатия не может 8ЛЛектиДно ра2отать на ОиЛр
# отекстаМ МороОиМ криЯтоалгоритмоД сжать ОиЛр
# отекст Десьма тяжело Яо тоШ ЯростоШ Яричине что криЯ-р
# тогр
# аЛическая система должна лУ2>ми достКЯн>ми сЯосо2ами р
# иЙ2аДлять ОиЛротекст от очеДидн>М ДнКтр
# енниМ ЙаДисимостеШ а ЯотомК его 8нтр
# оЯия 2Кдет Десьма Д>сокоШ и Кж точно намного Д>Ое чемр
#  К откр>того текста ЯредстаДить се2е алгор
# итм сжатия котор>Ш 2> Мор
# оОо сжимал ЙаОКмленн>е данн>е доДольно тяжело Дедь дажер
#  интКитиДно Яонятно что сжатие Дсе4ело 2аЙир
# Кется на иЙ2>точности инЛорма4ии Д тексте ОиЛр
# оДание 8тК иЙ2>точность Кстраняет а Дместе с неШ Кстр
# аняет и ДоЙможность сжать текст

# %% [markdown]
# # STEP 5

# %% [markdown]
# # Я -> п
# # Д -> в
# # Л -> ф
# # 2 -> б

# %% [markdown]
# если сначала применять алгоритм криптографического преобр
# аЙования данн>М то окажется что алгор
# итм сжатия не может 8ффективно работать на Оифр
# отекстаМ МороОиМ криптоалгоритмов сжать Оифр
# отекст весьма тяжело по тоШ простоШ причине что крип-р
# тогр
# афическая система должна лУб>ми достКпн>ми способами р
# иЙбавлять Оифротекст от очевидн>М внКтр
# енниМ ЙависимостеШ а потомК его 8нтр
# опия бКдет весьма в>сокоШ и Кж точно намного в>Ое чемр
#  К откр>того текста представить себе алгор
# итм сжатия котор>Ш б> Мор
# оОо сжимал ЙаОКмленн>е данн>е довольно тяжело ведь дажер
#  интКитивно понятно что сжатие все4ело баЙир
# Кется на иЙб>точности информа4ии в тексте Оифр
# ование 8тК иЙб>точность Кстраняет а вместе с неШ Кстр
# аняет и воЙможность сжать текст

# %% [markdown]
# # STEP 6

# %% [markdown]
# # Й -> з
# # М -> х
# # 8 -> э
# # О -> ш

# %% [markdown]
# если сначала применять алгоритм криптографического преобразования данн>х то окажется что алгоритм сжатия не может эффективно работать на шифротекстах хороших криптоалгоритмов сжать шифр
# отекст весьма тяжело по тоШ простоШ причине что крип-р
# тогр
# афическая система должна лУб>ми достКпн>ми способами р
# избавлять шифротекст от очевидн>х внКтр
# енних зависимостеШ а потомК его энтр
# опия бКдет весьма в>сокоШ и Кж точно намного в>ше чемр
#  К откр>того текста представить себе алгор
# итм сжатия котор>Ш б> хор
# ошо сжимал зашКмленн>е данн>е довольно тяжело ведь дажер
#  интКитивно понятно что сжатие все4ело базир
# Кется на изб>точности информа4ии в тексте шифр
# ование этК изб>точность Кстраняет а вместе с неШ Кстр
# аняет и возможность сжать текст

# %% [markdown]
# # STEP 7

# %% [markdown]
# # Ш -> й
# # К -> у
# # > -> ы
# # У -> ю
# # 4 -> ц

# %% [markdown]
# если сначала применять алгоритм криптографического преобразования данных то окажется что алгоритм сжатия не может эффективно работать на шифротекстах хороших криптоалгоритмов сжать шифротекст весьма тяжело по той простой причине что криптографическая система должна любыми доступными способами избавлять шифротекст от очевидных внутренних зависимостей а потому его энтропия будет весьма высокой и уж точно намного выше чем у открытого текста представить себе алгоритм сжатия который бы хорошо сжимал зашумленные данные довольно тяжело ведь даже интуитивно понятно что сжатие всецело базируется на избыточности информации в тексте шифрование эту избыточность устраняет а вместе с ней устраняет и возможность сжать текст

# %% [markdown]
# # KEY:

# %% [markdown]
# # 12ДЕrtИЧЗШЩЪ<ШЯ+АБКЛМ4О>78УФ
